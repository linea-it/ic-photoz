# %% [markdown]
# python script_1.py /lustre/t0/scratch/users/heloisa.mengisztki/ ~/output.csv
# python script_1.py /lustre/t1/cl/lsst/pz_project/pcw_2023 ~/output.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("~/output.csv")
df
# Out:
#                                              comment
# 0  Test input mags truncated 4 decimal cases - sm...  \
# 1  Test input mags with all decimal cases - small...
# 2  Test input mags with all decimal cases - small...
# 3          Test large inputs (preproc max 150k rows)
# 4  Test read and write from Lustre T1. FlexZBoost...
# 5  Test input truncated 4 decimal cases - small f...
# 6            Test large inputs (preproc max 2M rows)
# 7  Test read and write from Lustre T1. FlexZBoost...
# 8  Test input mags truncated 4 decimal cases - sm...
#
#                               process_id                start
# 0              fzboost_trunc4_chunk_150k  1900-07-15 20:33:39  \
# 1  fzboost_all_dec_cases_chunk_150k_100x  1900-07-16 12:53:01
# 2           bpz_all_dec_cases_chunk_150k  1900-07-15 20:06:21
# 3                     test_io_chunk_150k  1900-07-15 19:53:01
# 4                       test_hardware_t1  1900-07-13 23:57:24
# ...

# %%
df = pd.read_csv("~/test/test_fzboost_trunc4_chunk_150k.csv")
grouped_counts = df.groupby('host').size()

print(grouped_counts), len(df)
# Out:
# host
# 10.148.0.11    142
# 10.148.0.12    142
# 10.148.0.13    146
# 10.148.0.14    140
# 10.148.0.15    137
# 10.148.0.16    142
# 10.148.0.17    147
# 10.148.0.18    142
# 10.148.0.19    142
# 10.148.0.27    143
# 10.148.0.28    145
# 10.148.0.29    145
# 10.148.0.30     74
# 10.148.0.31     73
# 10.148.0.32     75
# dtype: int64
# (None, 1935)

# %%
df.head()
# Out:
#    task_id           time_begin             time_end  time_diff
# 0        1  1900-07-15 20:33:40  1900-07-15 20:36:24      164.0  \
# 1       16  1900-07-15 20:33:41  1900-07-15 20:36:29      168.0
# 2       46  1900-07-15 20:33:42  1900-07-15 20:36:41      179.0
# 3       61  1900-07-15 20:33:42  1900-07-15 20:36:48      186.0
# 4       76  1900-07-15 20:33:42  1900-07-15 20:36:48      186.0
#
#                                            file_name  chunks         host
# 0  objectTable_tract_3261_DC2_2_2i_runs_DP0_2_v23...  141838  10.148.0.17
# 1  objectTable_tract_3442_DC2_2_2i_runs_DP0_2_v23...  138651  10.148.0.17
# 2  objectTable_tract_3831_DC2_2_2i_runs_DP0_2_v23...  148416  10.148.0.17
# 3  objectTable_tract_3448_DC2_2_2i_runs_DP0_2_v23...  140009  10.148.0.17
# 4  objectTable_tract_3080_DC2_2_2i_runs_DP0_2_v23...  142410  10.148.0.17

# %%
df.groupby('file_name').size()
# Out:
# file_name
# file_name                                                                                                   2
# inprogress_objectTable_tract_2897_DC2_2_2i_runs_DP0_2_v23_0_1_PREOPS-905_step3_1_20220317T233937Z-part0     1
# inprogress_objectTable_tract_2897_DC2_2_2i_runs_DP0_2_v23_0_1_PREOPS-905_step3_1_20220317T233937Z-part1     1
# inprogress_objectTable_tract_2897_DC2_2_2i_runs_DP0_2_v23_0_1_PREOPS-905_step3_1_20220317T233937Z-part10    1
# inprogress_objectTable_tract_2897_DC2_2_2i_runs_DP0_2_v23_0_1_PREOPS-905_step3_1_20220317T233937Z-part11    1
#                                                                                                            ..
# inprogress_objectTable_tract_5074_DC2_2_2i_runs_DP0_2_v23_0_1_PREOPS-905_step3_31_20220314T212509Z-part5    1
# inprogress_objectTable_tract_5074_DC2_2_2i_runs_DP0_2_v23_0_1_PREOPS-905_step3_31_20220314T212509Z-part6    1
# ...

# %%
'inprogress_objectTable_tract_3086_DC2_2_2i_runs_DP0_2_v23_0_1_PREOPS-905_step3_5_20220218T163030Z-part7.pq'

# %%
df = pd.read_csv("~/test/test_fzboost_trunc4_chunk_150k.csv")
grouped_counts = df.groupby('host').size()

df
# Out:
#       task_id           time_begin             time_end  time_diff
# 0           1  1900-07-15 20:33:40  1900-07-15 20:36:24      164.0  \
# 1          16  1900-07-15 20:33:41  1900-07-15 20:36:29      168.0
# 2          46  1900-07-15 20:33:42  1900-07-15 20:36:41      179.0
# 3          61  1900-07-15 20:33:42  1900-07-15 20:36:48      186.0
# 4          76  1900-07-15 20:33:42  1900-07-15 20:36:48      186.0
# ...       ...                  ...                  ...        ...
# 1930     1633  1900-07-15 20:42:13  1900-07-15 20:51:02      529.0
# 1931     1602  1900-07-15 20:41:59  1900-07-15 20:51:17      558.0
# 1932     1807  1900-07-15 20:43:59  1900-07-15 20:51:29      450.0
# 1933     1742  1900-07-15 20:43:22  1900-07-15 20:51:44      502.0
# 1934     1930  1900-07-15 20:44:45  1900-07-15 20:52:17      452.0
#
#                                               file_name  chunks         host
# 0     objectTable_tract_3261_DC2_2_2i_runs_DP0_2_v23...  141838  10.148.0.17
# ...

# %%
df = pd.read_csv("~/data/dp0.2_pre_processed_data.csv")
df
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 df = pd.read_csv("~/data/dp0.2_pre_processed_data.csv")
#       2 df
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
